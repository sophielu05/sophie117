# %%
def hello():
  print('hello')
hello()
# Out:
# hello

# %%
def hello(msg):
  print(msg)
hello('hello')
hello('good morning')
# Out:
# hello
# good morning

# %%
def hello(x,y=10):
  z = x + y
  print(z)

# %%
def hello(name,age):
  msg=f'{name} is {age} years old'
  print(msg)

# %%
def a(x,y):
  result=x=y*2
  return result


b=a(1,2)
c=a(2,3)
print(b,c)
# Out:
# 4 6

# %%
def a(x):
  result=0
  while result<10:
    result=result+x
    if result==5:
      return result
  return result


b=a(1)
c=a(2)
print(b,c)
# Out:
# 5 10

# %%
def tf(value):
 return 2*value-1
test_values=[0.0,0.0011,0.25,0.5,0,54,0.75,1.0]
scaled_values=[tf(value)for value in test_values]
print("Original values:",test_values)
print("Scaled values:",scaled_values)
# Out:
# Original values: [0.0, 0.0011, 0.25, 0.5, 0, 54, 0.75, 1.0]
# Scaled values: [-1.0, -0.9978, -0.5, 0.0, -1, 107, 0.5, 1.0]

# %%
def a(n):
  if n == 0 or n ==1:
    return 1
  else:
    return n+a(n-1)


print(a(3))
# Out:
# 6

# %%
with open('test.txt','w')as f1:
  f1.write('good morning')

# %%
import datetime
print(datetime.datetime.now())
print(datetime.date.today())
# Out:
# 2024-09-26 08:58:12.869498
# 2024-09-26

# %%
import datetime as dd
print(dd.datetime.now())
print(dd.date.today())
# Out:
# 2024-09-26 08:59:58.218310
# 2024-09-26

# %%
s=pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-bbca305a5733> in <cell line: 1>()
# ----> 1 s=pd.Series([1,3,5,np.nan,6,8])
#       2 s
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np
dates=pd.date_range("20130101",periods=6)
print(dates)
df = pd.DataFrame(np.random.randn(6, 4), index=dates,
columns=list("ABCD"))
print(df)
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')
#                    A         B         C         D
# 2013-01-01  0.701883  0.206210 -0.257356 -0.643633
# 2013-01-02  0.880593 -0.579828  0.363304 -0.427802
# 2013-01-03 -0.785776  0.463006 -0.314862 -0.954460
# 2013-01-04  0.462425 -0.624823 -1.398684  0.004409
# 2013-01-05  0.610001  0.021233 -0.366232  0.557523
# 2013-01-06 -1.653281 -0.128822  1.099689  1.186213

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.035974 -0.107171 -0.145690 -0.046292
# std    1.019514  0.431656  0.833038  0.801669
# min   -1.653281 -0.624823 -1.398684 -0.954460
# 25%   -0.473725 -0.467077 -0.353389 -0.589675
# 50%    0.536213 -0.053795 -0.286109 -0.211696
# 75%    0.678912  0.159966  0.208139  0.419245
# max    0.880593  0.463006  1.099689  1.186213

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.701883    0.880593   -0.785776    0.462425    0.610001   -1.653281
# B    0.206210   -0.579828    0.463006   -0.624823    0.021233   -0.128822
# C   -0.257356    0.363304   -0.314862   -1.398684   -0.366232    1.099689
# D   -0.643633   -0.427802   -0.954460    0.004409    0.557523    1.186213

# %%
df["A"]
df[0:3]
print(df)
# Out:
#                    A         B         C         D
# 2013-01-01  0.701883  0.206210 -0.257356 -0.643633
# 2013-01-02  0.880593 -0.579828  0.363304 -0.427802
# 2013-01-03 -0.785776  0.463006 -0.314862 -0.954460
# 2013-01-04  0.462425 -0.624823 -1.398684  0.004409
# 2013-01-05  0.610001  0.021233 -0.366232  0.557523
# 2013-01-06 -1.653281 -0.128822  1.099689  1.186213

# %%
df[df>0]
df[df["A"]>0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.701883  0.206210 -0.257356 -0.643633
# 2013-01-02  0.880593 -0.579828  0.363304 -0.427802
# 2013-01-04  0.462425 -0.624823 -1.398684  0.004409
# 2013-01-05  0.610001  0.021233 -0.366232  0.557523
